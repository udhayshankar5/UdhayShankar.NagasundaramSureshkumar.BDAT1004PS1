// %% [markdown]
// # Question 1

// %% [markdown]
// # What data type is each of the following?

// %%
using System;

namespace Problem
{
    class Program
    {
        static void Main(string[] args)
        {
            int a = 5;
            int b = 1;
            int c = 2;
            double d = 5.0;
            int e = 3;
            int[] f = { 5, 2, 1 };
            value(a);
            value(d);
            value(a > b);
            value('a');
            value(a * c);
            value('a' * c);
            value('a' * 'c');
            value(a / c);
            value(a % c);
            value(f);
            value(a == e);
            value(3.14);  // value of pi is 3.14

        static void value(object v)
        {
            Console.WriteLine(v.GetType());
        }

        }
    }
}

// %% [markdown]
// ![1.PNG](attachment:1.PNG)

// %% [markdown]
// # Question 2

// %% [markdown]
// # a) How many letters are there in 'Supercalifragilisticexpialidocious'?

// %%
            string s = "Supercalifragilisticexpialidocious";
            Console.WriteLine(s.Length);

// %% [markdown]
// Output : 34

// %% [markdown]
// # b) Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?

// %%
            string x = "Supercalifragilisticexpialidocious";
            string y = "ice";
            Console.WriteLine(x.Contains(y));

// %% [markdown]
// Output : True

// %% [markdown]
// # c) Which of the following words is the longest:
// # Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or Bababadalgharaghtakamminarronnkonn?

// %%
using System;

namespace Data_programming
{
    class Length
    {
        static void Main(string[] args)
        {
            string x = "Supercalifragilisticexpialidocious";
            string y = "Honorificabilitudinitatibus";
            string z = "Bababadalgharaghtakamminarronnkonn";

            if (x.Length > y.Length)
            {
                if (x.Length > z.Length)
                    Console.WriteLine(x + " is the longest word");
                else if (x.Length < z.Length)
                    Console.WriteLine(z + " is the longest word");
                else
                    Console.WriteLine( x + " and " + z + " are the longest words");
            }
            else if (x.Length < y.Length)
            {
                if (y.Length > z.Length)
                    Console.WriteLine(y + " is the longest word");
                else if (y.Length < z.Length)
                    Console.WriteLine(z + " is the longest word");
                else
                    Console.WriteLine( y + " and " + z + " are the longest words");
            }
            else
            {
                if (x.Length > z.Length)
                    Console.WriteLine(  x + " and " + y + " are the longest words");
                else if (x.Length < z.Length)
                    Console.WriteLine(z + " is the longest word");
                else
                    Console.WriteLine( x + ", " + y + ", and" + z + " have same length");
            }

        }
    }
}

// %% [markdown]
// Output : Supercalifragilisticexpialidocious and Bababadalgharaghtakamminarronnkonn are the longest words

// %% [markdown]
// # d) Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian', 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

// %%
using System;

namespace AtoZ
{
    class Dict
    {
        static void Main(string[] args)
        {
            Dict str = new Dict();
            string[] words = new string[]{"Berlioz", "Borodin", "Brian", "Bartok", "Bellini", "Buxtehude", "Bernstein"};
            str.Dictionary(words);
        }
        public void Dictionary(string[] words)
        {
            Array.Sort(words);
            Console.WriteLine($"The word {words[0]} comes first and {words[words.Length - 1]} comes last");
        }
    }
}

// %% [markdown]
// Output : The word Bartok comes first and Buxtehude comes last

// %% [markdown]
// # Question 3

// %% [markdown]
// # Implement function triangleArea(a,b,c) that takes as input the lengths of the 3 sides of a triangle and returns the area of the triangle. By Heron's formula, the area of a triangle with side lengths a, b, and c is s(s - a)(s -b)(s -c), where s = (a+b+c)/2.

// %%
using System;

namespace Tri
{
    class Formula
    {
        static void Main(string[] args)
        {
            double s, a, b, c, TotalArea;
            a = 2;
            b = 2;
            c = 2;
            Console.WriteLine("The values are " + a +','+ b + ',' + c);

            //Finding S
            s = (a + b + c) / 2;

            //Finding Total Area
            TotalArea = Math.Sqrt(s * (s - a) * (s - b) * (s - c));
            Console.WriteLine("Area of triangle is " + TotalArea);
        }
    }
}

// %% [markdown]
// Output : The values are 2,2,2
// Area of triangle is 1.7320508075688772

// %% [markdown]
// ![3.PNG](attachment:3.PNG)

// %% [markdown]
// # Question 4

// %% [markdown]
// # Write a program in C# Sharp to separate odd and even integers in separate arrays.
// # Go to the editor
// # Test Data :
// # Input the number of elements to be stored in the array :5
// # Input 5 elements in the array :
// # element - 0 : 25
// # element - 1 : 47
// # element - 2 : 42
// # element - 3 : 56
// # element - 4 : 32

// %%
using System;

namespace Numbers
{
    class OddorEven
    {
         public void FindingOddorEven(int[] arr)
            {
                string odd = "";
                string even = "";
            foreach (int i in arr)
                {
                    if (i % 2 == 0)
                    {
                        even = even + i + "\n";
                    }
                    else
                    {
                        odd = odd + i + "\n";
                    }
                }
                Console.WriteLine($"The even numbers are:\n{even}");
                Console.WriteLine($"The odd numbers are :\n{odd}");
            }
        static void Main(string[] args)
        {
            OddorEven num = new OddorEven();
            int[] arr = new int[] { 25, 47, 42, 56, 32 };
            num.FindingOddorEven(arr);

        }
    }
}

// %% [markdown]
// The even numbers are:
// 42,
// 56,
// 32
//
// The odd numbers are :
// 25,
// 47

// %% [markdown]
// ![4.PNG](attachment:4.PNG)

// %% [markdown]
// # Question 5

// %% [markdown]
// # a) Write a function inside(x,y,x1,y1,x2,y2) that returns True or False depending on whether the point (x,y) lies in the rectangle with lower left corner (x1,y1) and upper right corner (x2,y2).

// %%
using System;

namespace Rectangle
{
    public class Rect
    {
        public bool Inside(double x, double y, double x1, double y1, double x2, double y2)
        {
            if (x > x1 && x < x2 && y > y1 && y < y2)
            {
                return true;         
            }
            else
            {
                return false;
            }
        }

        static void Main(string[] args)
        {

            Rect corner = new Rect();
            bool value = corner.Inside(1, 1, 0, 0, 2, 3);
            Console.WriteLine($"Inside(1,1,0,0,2,3)\n{value}");
            value = corner.Inside(-1, -1, 0, 0, 2, 3);
            Console.WriteLine($"Inside(-1,-1,0,0,2,3)\n{value}");
        }
    }
}

// %% [markdown]
// ![5a.PNG](attachment:5a.PNG)

// %% [markdown]
// # b) Use function inside() from part a. to write an expression that tests whether the point (1,1) lies in both of the following rectangles: one with lower left corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower left corner (0.5, 0.2) and upper right corner (1.1, 2)

// %%
using System;

namespace Rectangle
{
    using System;

    namespace Rectangle
    {
        public class Rect
        {
            public bool Inside(double x, double y, double x1, double y1, double x2, double y2)
            {
                if (x > x1 && x < x2 && y > y1 && y < y2)
                {
                    return true;
                }
                else
                {
                    return false;
                }
            }

            static void Main(string[] args)
            {
                Rect corner = new Rect();
                bool value = (corner.Inside(1, 1, 0.3, 0.5, 1.1, 0.7) && corner.Inside(1, 1, 0.5, 0.2, 1.1, 2));
                Console.WriteLine($"The Result is {value}");
            }
        }
    }
}

// %% [markdown]
// ![5b.PNG](attachment:5b.PNG)
